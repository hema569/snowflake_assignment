# %%
%%sql -r dataframe_1
SELECT
    CURRENT_USER() AS CURRENT_USER,
    CURRENT_ROLE() AS CURRENT_ROLE,
    CURRENT_WAREHOUSE() AS CURRENT_WAREHOUSE,
    CURRENT_DATABASE() AS CURRENT_DATABASE,
    CURRENT_SCHEMA() AS CURRENT_SCHEMA;

# %%
%%sql -r dataframe_2
CREATE OR REPLACE DATABASE SNOWFLAKE_ASSIGNMENT;

# %%
%%sql -r dataframe_3
USE DATABASE SNOWFLAKE_ASSIGNMENT;

# %%
%%sql -r dataframe_4
CREATE OR REPLACE SCHEMA TUTORIAL;
USE SCHEMA TUTORIAL;

# %%
%%sql -r dataframe_5
CREATE OR REPLACE WAREHOUSE TUTORIAL_WH
WAREHOUSE_SIZE = 'XSMALL'
AUTO_SUSPEND = 60
AUTO_RESUME = TRUE;
USE WAREHOUSE TUTORIAL_WH;

# %%
%%sql -r dataframe_6
CREATE OR REPLACE TABLE STUDENTS (
    STUDENT_ID INT,
    NAME VARCHAR(50),
    DEPARTMENT VARCHAR(50),
    MARKS INT
);
INSERT INTO STUDENTS VALUES
(101, 'Hema', 'CSE', 92),
(102, 'Priya', 'CSE', 88),
(103, 'Anu', 'BDA', 95),
(104, 'Rahul', 'CSE', 81),
(105, 'Arun', 'BDA', 90);
SELECT * FROM STUDENTS;

# %%
%%sql -r dataframe_7
INSERT INTO STUDENTS
VALUES (106, 'Kavi', 'CSE', 87);
SELECT * FROM STUDENTS;

# %%
%%sql -r dataframe_8
UPDATE STUDENTS
SET MARKS = 94
WHERE STUDENT_ID = 101;
SELECT * FROM STUDENTS
WHERE STUDENT_ID = 101;

# %%
%%sql -r dataframe_9
DELETE FROM STUDENTS
WHERE STUDENT_ID = 106;
SELECT * FROM STUDENTS;

# %%
%%sql -r dataframe_10
CREATE OR REPLACE STAGE STUDENT_STAGE;
SHOW STAGES;

# %%
%%sql -r dataframe_11

# %%
%%sql -r dataframe_3
SELECT QUERY_ID, QUERY_TEXT
FROM TABLE(INFORMATION_SCHEMA.QUERY_HISTORY())
WHERE QUERY_TEXT ILIKE 'DELETE FROM EMPLOYEES%'
ORDER BY START_TIME DESC
LIMIT 1;

# %%
%%sql -r dataframe_6
SELECT QUERY_ID, QUERY_TEXT
FROM TABLE(INFORMATION_SCHEMA.QUERY_HISTORY())
WHERE QUERY_TEXT ILIKE '%DELETE FROM EMPLOYEES%'
ORDER BY START_TIME DESC
LIMIT 1;

# %%
%%sql -r dataframe_8
USE DATABASE SNOWFLAKE_ASSIGNMENT;
USE SCHEMA TUTORIAL;
USE WAREHOUSE TUTORIAL_WH;

INSERT INTO EMPLOYEES
SELECT *
FROM EMPLOYEES
BEFORE (
    STATEMENT => '01c71a7a-0002-9e9b-000e-dd4a00019432'
)
WHERE EMP_ID = 2;

SELECT *
FROM EMPLOYEES
ORDER BY EMP_ID;
